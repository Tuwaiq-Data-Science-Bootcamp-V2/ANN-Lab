# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import category_encoders as ce
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('Bank_Customers.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
df['Gender']=label_encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France       0   42
# 1             2    15647311       Hill          608     Spain       0   41
# 2             3    15619304       Onio          502    France       0   42
# 3             4    15701354       Boni          699    France       0   39
# 4             5    15737888   Mitchell          850     Spain       0   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France       1   39
# 9996       9997    15569892  Johnstone          516    France       1   35
# 9997       9998    15584532        Liu          709    France       0   36
# 9998       9999    15682355  Sabbatini          772   Germany       1   42
# 9999      10000    15628319     Walker          792    France       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
onehot_encoder = OneHotEncoder(sparse=False)

# %%
onehot = ce.OneHotEncoder(cols='Geography').fit(df)
df = onehot.transform(df)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography_1  Geography_2  \
# 0             1    15634602   Hargrave          619            1            0
# 1             2    15647311       Hill          608            0            1
# 2             3    15619304       Onio          502            1            0
# 3             4    15701354       Boni          699            1            0
# 4             5    15737888   Mitchell          850            0            1
# ...         ...         ...        ...          ...          ...          ...
# 9995       9996    15606229   Obijiaku          771            1            0
# 9996       9997    15569892  Johnstone          516            1            0
# 9997       9998    15584532        Liu          709            1            0
# 9998       9999    15682355  Sabbatini          772            0            0
# 9999      10000    15628319     Walker          792            1            0
#
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography_1  Geography_2  \
# 0             1    15634602   Hargrave          619            1            0
# 1             2    15647311       Hill          608            0            1
# 2             3    15619304       Onio          502            1            0
# 3             4    15701354       Boni          699            1            0
# 4             5    15737888   Mitchell          850            0            1
# ...         ...         ...        ...          ...          ...          ...
# 9995       9996    15606229   Obijiaku          771            1            0
# 9996       9997    15569892  Johnstone          516            1            0
# 9997       9998    15584532        Liu          709            1            0
# 9998       9999    15682355  Sabbatini          772            0            0
# 9999      10000    15628319     Walker          792            1            0
#
# ...

# %%
df.drop(['CustomerId' , 'Surname' , 'RowNumber'] , axis=1 , inplace=True)

# %%
X = df.drop(['Exited'] , axis=1)
y = df['Exited']

# %%
X
# Out:
#       CreditScore  Geography_1  Geography_2  Geography_3  Gender  Age  Tenure  \
# 0             619            1            0            0       0   42       2
# 1             608            0            1            0       0   41       1
# 2             502            1            0            0       0   42       8
# 3             699            1            0            0       0   39       1
# 4             850            0            1            0       0   43       2
# ...           ...          ...          ...          ...     ...  ...     ...
# 9995          771            1            0            0       1   39       5
# 9996          516            1            0            0       1   35      10
# 9997          709            1            0            0       0   36       7
# 9998          772            0            0            1       1   42       3
# 9999          792            1            0            0       0   28       4
#
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.1 )

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
ann = Sequential()

# %%
ann.add(Dense(units=80 , activation='relu'))
ann.add(Dense(units=80 , activation='relu'))
ann.add(Dense(units=1 , activation='sigmoid'))

# %%
ann.compile(optimizer='Adam' , loss='binary_crossentropy' , metrics=['accuracy'])

# %%
ann.fit(X_train , y_train , batch_size=32 , epochs=70 ,shuffle=True )
# Out:
# Epoch 1/70
# 282/282 [==============================] - 2s 3ms/step - loss: 0.4245 - accuracy: 0.8228
# Epoch 2/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3618 - accuracy: 0.8522
# Epoch 3/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3485 - accuracy: 0.8539
# Epoch 4/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3413 - accuracy: 0.8580
# Epoch 5/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3373 - accuracy: 0.8590
# Epoch 6/70
# 282/282 [==============================] - 1s 4ms/step - loss: 0.3323 - accuracy: 0.8614
# Epoch 7/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3288 - accuracy: 0.8609
# Epoch 8/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3279 - accuracy: 0.8612
# Epoch 9/70
# 282/282 [==============================] - 1s 3ms/step - loss: 0.3248 - accuracy: 0.8652
# Epoch 10/70
# ...

# %%
ann.predict(sc.transform([[600 , 1 , 0 , 0 ,1 , 40 , 3 , 60000 , 2 , 1 , 1 , 50000]]))
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([[0.1172469]], dtype=float32)
